# %% [markdown]
# ### Viewing results
#
# After completing model runs, open a terminal and run:
#
# ```bash
# mlflow ui
# ```
# Then open `http://localhost:5000` to compare all your runs visually.

# %%
# !mlflow ui
# Out:
# ^C
